# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil=Image.open("RGB_Matte_Hierarchy.png")

# %%
arr=np.array(pil)

# %%
arr.shape
# Out:
# (480, 640, 3)

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480 at 0x25BE9435648>

# %%
red =arr[100:200, :300]

# %%
plt.imshow(red)

# %%
red =arr[100:200, :, 2]

# %%
plt.imshow(red)

# %%
pil=Image.open("Thor.jpg")

# %%
arr=np.array(pil)

# %%
arr.shape
# Out:
# (237, 212, 3)

# %%
plt.imshow(arr)

# %%
work=arr.copy()

# %%
work[:, :, [1,2]].shape
# Out:
# (237, 212, 2)

# %%
work[:, :, [1,2]]=0

# %%
plt.imshow(work)

# %%
work[:, :, [1,2]]=255

# %%
plt.imshow(work)

# %%
gray=arr.mean(axis=2)

# %%
plt.imshow(gray)

# %%
plt.imshow(gray,cmap="gray")#cmap is colormap
